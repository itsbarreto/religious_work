# %%
'''

Criado em 25.04.2018 para criar um arquivo com conjugacoes dos verbos da lingua portuguesa.

Fluxo:
01. Pegar a lista dos verbos regulares.
02. Capturar a conjucao.
03. Fazer o mesmo com os verbos irregulares.

'''


from bs4 import BeautifulSoup, NavigableString, Tag
import requests
import re
import pandas as pd
import numpy as np
import time
from threading import Thread
import _thread
import platform
from itertools import chain
def get_sopa(url):
    req = requests.get(url)
    data = req.text
    soup = BeautifulSoup(data, "html5lib")
    return soup

def get_verbos(url):
    sopa = get_sopa(url)
    lista_verbos = []
    for divtag in sopa.find_all('div', {'class': 'wrapper'}):
        for a in divtag.find_all('a'):
            if 'verbo' in a['href']:
                lista_verbos.append(a['href'])
    return lista_verbos

def get_dados_verbo(url,i):
    print('%i. Pesquisados' %i, end='\t')
    sopa = get_sopa(url)
    dados = []
    try:
        verbo = sopa.find('h1',{'class': 'nmt'}).text.lower().replace('verbo','').strip()
        div_info = sopa.find_all('div',{'class': 'info-v'})[0]
        infos_procuradas = ['gerúndio','particípio passado','infinitivo']
        for st in div_info.find_all('strong'):
            print(st.contents[0].strip())
            if st.contents[0].strip().lower() in infos_procuradas:
                sp_info = st.findNext('span').find_all('span',{'class' : 'f'})[0]
                if sp_info.contents[0]:
                    dados.append(
                    {
                    'verbo' : verbo,
                    #'modo' : modo,
                    'tempo' : st.contents[0].strip().lower(),
                    'pessoa' : '',
                    'palavra' : sp_info.contents[0].strip().lower()
                    })


        print('Verbo: %s' %verbo)
        pessoas = ['eu','tu','ele','nós','vós','eles']
        for divtag in sopa.find_all('div', {'class': 'tempos'}):
            print(len(divtag))
            for divc in divtag.find_all('div', {'class': 'tempo-conjugacao'}):
                tempo = divc.find('h4').contents[0].strip().lower()
                for p in pessoas:
                    try:
                        tempos_dif = ['imperativo afirmativo', 'imperativo negativo', 'infinitivo pessoal']
                        sp_pss = divc.find(text=re.compile(p))
                        sp_palavra = sp_pss.findNext('span') if tempo not in tempos_dif else sp_pss.findPrevious('span').findPrevious('span')
                        dados.append(
                        {
                        'verbo' : verbo,
                        #'modo' : modo,
                        'tempo' : tempo,
                        'pessoa' : p,
                        'palavra' : sp_palavra.contents[0].strip().lower() if tempo not in tempos_dif else sp_palavra.contents[0].strip().lower()
                        })
                    except Exception as e:
                        print(e)
                        pass
    except Exception as e:
        print(e)
        pass
    return dados

# %%
localtime = time.asctime( time.localtime(time.time()) )
print('Inicio do processamento ', localtime)
url_base = 'https://www.conjugacao.com.br'
lista_verbos = list(chain(*[get_verbos(url_base+'/verbos-populares/' + str(i)) for i in range(1,202)]))
#lista_verbos = ['/verbo-contrapropor/']
# Out:
# Inicio do processamento  Thu Apr 26 08:50:48 2018

# %%
print('%i verbos para capturar' %len(lista_verbos))
print('Inicio da captura das conjugacoes %s' %time.asctime( time.localtime(time.time()) ))
# Out:
# 20100 verbos para capturar
# Inicio da captura das conjugacoes Thu Apr 26 08:54:36 2018

# %%
# Out:
# ['/verbo-ir/',
#  '/verbo-ser/',
#  '/verbo-fazer/',
#  '/verbo-amar/',
#  '/verbo-estar/',
#  '/verbo-ver/',
#  '/verbo-ter/',
#  '/verbo-vir/',
#  '/verbo-poder/',
#  '/verbo-dar/',
#  '/verbo-haver/',
#  '/verbo-partir/',
#  '/verbo-comer/',
#  '/verbo-por/',
#  '/verbo-dizer/',
#  '/verbo-estudar/',
#  '/verbo-falar/',
#  '/verbo-rir/',
#  '/verbo-cantar/',
#  '/verbo-sair/',
#  '/verbo-querer/',
#  '/verbo-trazer/',
#  '/verbo-vender/',
#  '/verbo-beber/',
#  '/verbo-correr/',
#  '/verbo-ler/',
#  '/verbo-sorrir/',
#  '/verbo-saber/',
#  '/verbo-sentir/',
#  '/verbo-dormir/',
#  '/verbo-agir/',
#  '/verbo-andar/',
#  '/verbo-brincar/',
#  '/verbo-escrever/',
#  '/verbo-gostar/',
#  '/verbo-corrigir/',
#  '/verbo-ouvir/',
#  '/verbo-pedir/',
#  '/verbo-jogar/',
#  '/verbo-chegar/',
#  '/verbo-receber/',
#  '/verbo-caber/',
#  '/verbo-dancar/',
#  '/verbo-pensar/',
#  '/verbo-ficar/',
#  '/verbo-chamar/',
#  '/verbo-expor/',
#  '/verbo-crer/',
#  '/verbo-lembrar/',
#  '/verbo-nascer/',
#  '/verbo-encontrar/',
#  '/verbo-manter/',
#  '/verbo-abrir/',
#  '/verbo-cair/',
#  '/verbo-comecar/',
#  '/verbo-intervir/',
#  '/verbo-usar/',
#  '/verbo-aprender/',
#  '/verbo-pular/',
#  '/verbo-conhecer/',
#  '/verbo-conseguir/',
#  '/verbo-voar/',
#  '/verbo-perder/',
#  '/verbo-viajar/',
#  '/verbo-passear/',
#  '/verbo-comprar/',
#  '/verbo-viver/',
#  '/verbo-dividir/',
#  '/verbo-dirigir/',
#  '/verbo-proteger/',
#  '/verbo-trabalhar/',
#  '/verbo-voltar/',
#  '/verbo-subir/',
#  '/verbo-reaver/',
#  '/verbo-levar/',
#  '/verbo-dever/',
#  '/verbo-compor/',
#  '/verbo-entender/',
#  '/verbo-achar/',
#  '/verbo-parar/',
#  '/verbo-olhar/',
#  '/verbo-cumprir/',
#  '/verbo-passar/',
#  '/verbo-colocar/',
#  '/verbo-imprimir/',
#  '/verbo-medir/',
#  '/verbo-acordar/',
#  '/verbo-seguir/',
#  '/verbo-procurar/',
#  '/verbo-fugir/',
#  '/verbo-precisar/',
#  '/verbo-tossir/',
#  '/verbo-deixar/',
#  '/verbo-conversar/',
#  '/verbo-assistir/',
#  '/verbo-desejar/',
#  '/verbo-mexer/',
#  '/verbo-lavar/',
#  '/verbo-fingir/',
#  '/verbo-esquecer/',
#  '/verbo-esperar/',
#  '/verbo-atender/',
#  '/verbo-mandar/',
#  '/verbo-valer/',
#  '/verbo-chorar/',
#  '/verbo-morar/',
#  '/verbo-sumir/',
#  '/verbo-almocar/',
#  '/verbo-bater/',
#  '/verbo-avisar/',
#  '/verbo-fechar/',
#  '/verbo-nadar/',
#  '/verbo-dispor/',
#  '/verbo-participar/',
#  '/verbo-acontecer/',
#  '/verbo-contar/',
#  '/verbo-mentir/',
#  '/verbo-prover/',
#  '/verbo-descer/',
#  '/verbo-caminhar/',
#  '/verbo-entrar/',
#  '/verbo-convidar/',
#  '/verbo-desistir/',
#  '/verbo-possuir/',
#  '/verbo-agradecer/',
#  '/verbo-buscar/',
#  '/verbo-julgar/',
#  '/verbo-vestir/',
#  '/verbo-sentar/',
#  '/verbo-adquirir/',
#  '/verbo-mudar/',
#  '/verbo-ferir/',
#  '/verbo-sonhar/',
#  '/verbo-pegar/',
#  '/verbo-continuar/',
#  '/verbo-excluir/',
#  '/verbo-ajudar/',
#  '/verbo-acabar/',
#  '/verbo-ganhar/',
#  '/verbo-encher/',
#  '/verbo-entreter/',
#  '/verbo-tomar/',
#  '/verbo-pagar/',
#  '/verbo-escolher/',
#  '/verbo-realizar/',
#  '/verbo-informar/',
#  '/verbo-requerer/',
#  '/verbo-apresentar/',
#  '/verbo-servir/',
#  '/verbo-divertir/',
#  '/verbo-permitir/',
#  '/verbo-beijar/',
#  '/verbo-existir/',
#  '/verbo-preferir/',
#  '/verbo-morrer/',
#  '/verbo-ligar/',
#  '/verbo-propor/',
#  '/verbo-doer/',
#  '/verbo-chover/',
#  '/verbo-parecer/',
#  '/verbo-colorir/',
#  '/verbo-decidir/',
#  '/verbo-casar/',
#  '/verbo-vencer/',
#  '/verbo-levantar/',
#  '/verbo-repetir/',
#  '/verbo-conter/',
#  '/verbo-sofrer/',
#  '/verbo-surgir/',
#  '/verbo-descobrir/',
#  '/verbo-construir/',
#  '/verbo-preocupar/',
#  '/verbo-gritar/',
#  '/verbo-zoar/',
#  '/verbo-aproveitar/',
#  '/verbo-permanecer/',
#  '/verbo-conjugar/',
#  '/verbo-aparecer/',
#  '/verbo-prever/',
#  '/verbo-tornar/',
#  '/verbo-ensinar/',
#  '/verbo-discutir/',
#  '/verbo-encaminhar/',
#  '/verbo-mostrar/',
#  '/verbo-respeitar/',
#  '/verbo-precaver/',
#  '/verbo-marcar/',
#  '/verbo-ceder/',
#  '/verbo-destruir/',
#  '/verbo-ingerir/',
#  '/verbo-imaginar/',
#  '/verbo-crescer/',
#  '/verbo-rever/',
#  '/verbo-odiar/',
#  '/verbo-enviar/',
#  '/verbo-salvar/',
#  '/verbo-aguardar/',
#  '/verbo-tentar/',
#  '/verbo-oferecer/',
#  '/verbo-exercer/',
#  '/verbo-cortar/',
#  '/verbo-entregar/',
#  '/verbo-compartilhar/',
#  '/verbo-compreender/',
#  '/verbo-plantar/',
#  '/verbo-varrer/',
#  '/verbo-responder/',
#  '/verbo-limpar/',
#  '/verbo-merecer/',
#  '/verbo-atrair/',
#  '/verbo-polir/',
#  '/verbo-iniciar/',
#  '/verbo-observar/',
#  '/verbo-garantir/',
#  '/verbo-prender/',
#  '/verbo-tirar/',
#  '/verbo-deter/',
#  '/verbo-aceitar/',
#  '/verbo-perguntar/',
#  '/verbo-analisar/',
#  '/verbo-terminar/',
#  '/verbo-educar/',
#  '/verbo-satisfazer/',
#  '/verbo-incluir/',
#  '/verbo-acompanhar/',
#  '/verbo-repor/',
#  '/verbo-perceber/',
#  '/verbo-aderir/',
#  '/verbo-provir/',
#  '/verbo-falir/',
#  '/verbo-ocorrer/',
#  '/verbo-reter/',
#  '/verbo-adequar/',
#  '/verbo-alcancar/',
#  '/verbo-expressar/',
#  '/verbo-criar/',
#  '/verbo-copiar/',
#  '/verbo-acreditar/',
#  '/verbo-indicar/',
#  '/verbo-arrumar/',
#  '/verbo-perdoar/',
#  '/verbo-pintar/',
#  '/verbo-produzir/',
#  '/verbo-calar/',
#  '/verbo-apagar/',
#  '/verbo-esconder/',
#  '/verbo-resistir/',
#  '/verbo-resolver/',
#  '/verbo-acender/',
#  '/verbo-emitir/',
#  '/verbo-repartir/',
#  '/verbo-considerar/',
#  '/verbo-pentear/',
#  '/verbo-refletir/',
#  '/verbo-feder/',
#  '/verbo-despedir/',
#  '/verbo-curtir/',
#  '/verbo-quebrar/',
#  '/verbo-insistir/',
#  '/verbo-confundir/',
#  '/verbo-cuspir/',
#  '/verbo-orientar/',
#  '/verbo-comparecer/',
#  '/verbo-obter/',
#  '/verbo-honrar/',
#  '/verbo-distrair/',
#  '/verbo-matar/',
#  '/verbo-lancar/',
#  '/verbo-escutar/',
#  '/verbo-visitar/',
#  '/verbo-convir/',
#  '/verbo-cobrir/',
#  '/verbo-retirar/',
#  '/verbo-tocar/',
#  '/verbo-defender/',
#  '/verbo-conduzir/',
#  '/verbo-lambuzar/',
#  '/verbo-abolir/',
#  '/verbo-separar/',
#  '/verbo-atrasar/',
#  '/verbo-impor/',
#  '/verbo-deitar/',
#  '/verbo-semear/',
#  '/verbo-negar/',
#  '/verbo-aproximar/',
#  '/verbo-invadir/',
#  '/verbo-puxar/',
#  '/verbo-guardar/',
#  '/verbo-preparar/',
#  '/verbo-prometer/',
#  '/verbo-enganar/',
#  '/verbo-juntar/',
#  '/verbo-formar/',
#  '/verbo-adorar/',
#  '/verbo-virar/',
#  '/verbo-explicar/',
#  '/verbo-banhar/',
#  '/verbo-reclamar/',
#  '/verbo-proporcionar/',
#  '/verbo-lidar/',
#  '/verbo-errar/',
#  '/verbo-prestar/',
#  '/verbo-colher/',
#  '/verbo-cuidar/',
#  '/verbo-vomitar/',
#  '/verbo-aplicar/',
#  '/verbo-importar/',
#  '/verbo-escovar/',
#  '/verbo-reconhecer/',
#  '/verbo-evitar/',
#  '/verbo-cheirar/',
#  '/verbo-reger/',
#  '/verbo-cometer/',
#  '/verbo-desenvolver/',
#  '/verbo-obedecer/',
#  '/verbo-perseguir/',
#  '/verbo-namorar/',
#  '/verbo-cozinhar/',
#  '/verbo-afastar/',
#  '/verbo-lutar/',
#  '/verbo-ansiar/',
#  '/verbo-saborear/',
#  '/verbo-conquistar/',
#  '/verbo-distinguir/',
#  '/verbo-despir/',
#  '/verbo-alegrar/',
#  '/verbo-mover/',
#  '/verbo-reunir/',
#  '/verbo-demorar/',
#  '/verbo-supor/',
#  '/verbo-pretender/',
#  '/verbo-faltar/',
#  '/verbo-engolir/',
#  '/verbo-abracar-2/',
#  '/verbo-extrair/',
#  '/verbo-jantar/',
#  '/verbo-desocupar/',
#  '/verbo-doar/',
#  '/verbo-queimar/',
#  '/verbo-telefonar/',
#  '/verbo-abandonar/',
#  '/verbo-acostumar/',
#  '/verbo-diminuir/',
#  '/verbo-concordar/',
#  '/verbo-utilizar/',
#  '/verbo-aguar/',
#  '/verbo-adivinhar/',
#  '/verbo-surpreender/',
#  '/verbo-ignorar/',
#  '/verbo-provar/',
#  '/verbo-animar/',
#  '/verbo-basear/',
#  '/verbo-descansar/',
#  '/verbo-competir/',
#  '/verbo-causar/',
#  '/verbo-optar/',
#  '/verbo-arranjar/',
#  '/verbo-desenhar/',
#  '/verbo-atravessar/',
#  '/verbo-segurar/',
#  '/verbo-apanhar/',
#  '/verbo-confirmar/',
#  '/verbo-recear/',
#  '/verbo-dedicar/',
#  '/verbo-atingir/',
#  '/verbo-efetuar/',
#  '/verbo-concluir/',
#  '/verbo-unir/',
#  '/verbo-instruir/',
#  '/verbo-roubar/',
#  '/verbo-refazer/',
#  '/verbo-gemer/',
#  '/verbo-escorrer/',
#  '/verbo-cagar/',
#  '/verbo-render/',
#  '/verbo-suar/',
#  '/verbo-fumar/',
#  '/verbo-representar/',
#  '/verbo-encerrar/',
#  '/verbo-emprestar/',
#  '/verbo-morder/',
#  '/verbo-atribuir/',
#  '/verbo-trocar/',
#  '/verbo-gastar/',
#  '/verbo-punir/',
#  '/verbo-presentear/',
#  '/verbo-perturbar/',
#  '/verbo-iluminar/',
#  '/verbo-devolver/',
#  '/verbo-comunicar/',
#  '/verbo-contribuir/',
#  '/verbo-desfazer/',
#  '/verbo-divulgar/',
#  '/verbo-constituir/',
#  '/verbo-exigir/',
#  '/verbo-publicar/',
#  '/verbo-percorrer/',
#  '/verbo-tratar/',
#  '/verbo-definir/',
#  '/verbo-notar/',
#  '/verbo-prescindir/',
#  '/verbo-praticar/',
#  '/verbo-superar/',
#  '/verbo-sugerir/',
#  '/verbo-alterar/',
#  '/verbo-festejar/',
#  '/verbo-transformar/',
#  '/verbo-conviver/',
#  '/verbo-parabenizar/',
#  '/verbo-opor/',
#  '/verbo-erguer/',
#  '/verbo-apoiar/',
#  '/verbo-aquecer/',
#  '/verbo-encarar/',
#  '/verbo-recolher/',
#  '/verbo-confiar/',
#  '/verbo-obrigar/',
#  '/verbo-agradar/',
#  '/verbo-amarrar/',
#  '/verbo-florir/',
#  '/verbo-impedir/',
#  '/verbo-saltar/',
#  '/verbo-renovar/',
#  '/verbo-fornecer/',
#  '/verbo-falhar/',
#  '/verbo-mediar/',
#  '/verbo-consumir/',
#  '/verbo-montar/',
#  '/verbo-fortalecer/',
#  '/verbo-prezar/',
#  '/verbo-bastar/',
#  '/verbo-anunciar/',
#  '/verbo-manifestar/',
#  '/verbo-escanear/',
#  '/verbo-acrescentar/',
#  '/verbo-gozar/',
#  '/verbo-socorrer/',
#  '/verbo-louvar/',
#  '/verbo-substituir/',
#  '/verbo-agredir/',
#  '/verbo-focar/',
#  '/verbo-duvidar/',
#  '/verbo-reagir/',
#  '/verbo-expandir/',
#  '/verbo-proibir/',
#  '/verbo-assumir/',
#  '/verbo-apreciar/',
#  '/verbo-ocupar/',
#  '/verbo-desaparecer/',
#  '/verbo-dominar/',
#  '/verbo-inverter/',
#  '/verbo-meter/',
#  '/verbo-livrar/',
#  '/verbo-avancar/',
#  '/verbo-frear/',
#  '/verbo-tender/',
#  '/verbo-combater/',
#  '/verbo-afirmar/',
#  '/verbo-controlar/',
#  '/verbo-inspirar/',
#  '/verbo-adormecer/',
#  '/verbo-aplaudir/',
#  '/verbo-empurrar/',
#  '/verbo-magoar/',
#  '/verbo-deslocar/',
#  '/verbo-prevenir/',
#  '/verbo-avistar/',
#  '/verbo-roer/',
#  '/verbo-ultrapassar/',
#  '/verbo-submeter/',
#  '/verbo-pesquisar/',
#  '/verbo-pescar/',
#  '/verbo-eleger/',
#  '/verbo-promover/',
#  '/verbo-demonstrar/',
#  '/verbo-remediar/',
#  '/verbo-jazer/',
#  '/verbo-consertar/',
#  '/verbo-carregar/',
#  '/verbo-temer/',
#  '/verbo-soltar/',
#  '/verbo-repolir/',
#  '/verbo-tecer/',
#  '/verbo-demolir/',
#  '/verbo-retornar/',
#  '/verbo-bloquear/',
#  '/verbo-comemorar/',
#  '/verbo-explodir/',
#  '/verbo-fixar/',
#  '/verbo-estimular/',
#  '/verbo-respirar/',
#  '/verbo-averiguar/',
#  '/verbo-nutrir/',
#  '/verbo-resumir/',
#  '/verbo-convencer/',
#  '/verbo-traduzir/',
#  '/verbo-necessitar/',
#  '/verbo-assinar/',
#  '/verbo-calcular/',
#  '/verbo-adicionar/']

# %%
conjugacoes = []
_ = [conjugacoes.extend(get_dados_verbo(url_base + v,i)) for i,v  in enumerate(lista_verbos)]
print('%i conjugacoes' %len(conjugacoes))
pd.DataFrame(conjugacoes).to_csv('C:\\Work\\csv\\verbos.csv')
#pd.DataFrame(conjugacoes).to_csv('verbos.csv')
localtime = time.asctime( time.localtime(time.time()) )
print('Término do processamento ', localtime)
# Out:
# 0. Pesquisados	Gerúndio
# Particípio passado
# Infinitivo
# Verbo: ir
# 7
# 'NoneType' object is not callable
# 'NoneType' object is not callable
# 4
# 'NoneType' object is not callable
# 3
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 2
# 7
# 'NoneType' object is not callable
# 'NoneType' object is not callable
# 4
# 'NoneType' object is not callable
# 3
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 2
# 7
# 'NoneType' object is not callable
# 'NoneType' object is not callable
# 4
# 'NoneType' object is not callable
# 3
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 2
# 1. Pesquisados	Gerúndio
# Particípio passado
# Infinitivo
# Verbo: ser
# 7
# 'NoneType' object is not callable
# 'NoneType' object is not callable
# 4
# 'NoneType' object is not callable
# 3
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 2
# 7
# 'NoneType' object is not callable
# 'NoneType' object is not callable
# 4
# 'NoneType' object is not callable
# 3
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 2
# 2. Pesquisados	Gerúndio
# Particípio passado
# Infinitivo
# Verbo: fazer
# 7
# 'NoneType' object is not callable
# 'NoneType' object is not callable
# 4
# 'NoneType' object is not callable
# 3
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 2
# 7
# 'NoneType' object is not callable
# 'NoneType' object is not callable
# 4
# 'NoneType' object is not callable
# 3
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 2
# 7
# 'NoneType' object is not callable
# 'NoneType' object is not callable
# 4
# 'NoneType' object is not callable
# 3
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 2
# 3. Pesquisados	Gerúndio
# Particípio passado
# Infinitivo
# Verbo: amar
# 7
# 'NoneType' object is not callable
# 'NoneType' object is not callable
# 4
# 'NoneType' object is not callable
# 3
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 2
# 7
# 'NoneType' object is not callable
# 'NoneType' object is not callable
# 4
# 'NoneType' object is not callable
# 3
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 2
# 7
# 'NoneType' object is not callable
# 'NoneType' object is not callable
# 4
# 'NoneType' object is not callable
# 3
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 2
# 4. Pesquisados	Gerúndio
# Particípio passado
# Infinitivo
# Verbo: estar
# 7
# 'NoneType' object is not callable
# 'NoneType' object is not callable
# 4
# 'NoneType' object is not callable
# 3
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 2
# 7
# 'NoneType' object is not callable
# 'NoneType' object is not callable
# 4
# 'NoneType' object is not callable
# 3
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 2
# 5. Pesquisados	Gerúndio
# Particípio passado
# Infinitivo
# Verbo: ver
# 7
# 'NoneType' object is not callable
# 'NoneType' object is not callable
# 4
# 'NoneType' object is not callable
# 3
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 2
# 7
# 'NoneType' object is not callable
# 'NoneType' object is not callable
# 4
# 'NoneType' object is not callable
# 3
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 2
# 7
# 'NoneType' object is not callable
# 'NoneType' object is not callable
# 4
# 'NoneType' object is not callable
# 3
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 2
# 6. Pesquisados	Gerúndio
# Particípio passado
# Infinitivo
# Verbo: ter
# 7
# 'NoneType' object is not callable
# 'NoneType' object is not callable
# 4
# 'NoneType' object is not callable
# 3
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 2
# 7
# 'NoneType' object is not callable
# 'NoneType' object is not callable
# 4
# 'NoneType' object is not callable
# 3
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 2
# 7
# 'NoneType' object is not callable
# 'NoneType' object is not callable
# 4
# 'NoneType' object is not callable
# 3
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 2
# 7. Pesquisados	Gerúndio
# Particípio passado
# Infinitivo
# Verbo: vir
# 7
# 'NoneType' object is not callable
# 'NoneType' object is not callable
# 4
# 'NoneType' object is not callable
# 3
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 2
# 7
# 'NoneType' object is not callable
# 'NoneType' object is not callable
# 4
# 'NoneType' object is not callable
# 3
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 2
# 7
# 'NoneType' object is not callable
# 'NoneType' object is not callable
# 4
# 'NoneType' object is not callable
# 3
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 2
# 8. Pesquisados	Gerúndio
# Particípio passado
# Infinitivo
# Verbo: poder
# 7
# 'NoneType' object is not callable
# 'NoneType' object is not callable
# 4
# 'NoneType' object is not callable
# 3
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 2
# 7
# 'NoneType' object is not callable
# 'NoneType' object is not callable
# 4
# 'NoneType' object is not callable
# 2
# 9. Pesquisados	Gerúndio
# Particípio passado
# Infinitivo
# Verbo: dar
# 7
# 'NoneType' object is not callable
# 'NoneType' object is not callable
# 4
# 'NoneType' object is not callable
# 3
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 2
# 7
# 'NoneType' object is not callable
# 'NoneType' object is not callable
# 4
# 'NoneType' object is not callable
# 3
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 2
# 7
# 'NoneType' object is not callable
# 'NoneType' object is not callable
# 4
# 'NoneType' object is not callable
# 3
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 2
# 10. Pesquisados	Gerúndio
# Particípio passado
# Infinitivo
# Verbo: haver
# 7
# 'NoneType' object is not callable
# 'NoneType' object is not callable
# 4
# 'NoneType' object is not callable
# 3
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 2
# 7
# 'NoneType' object is not callable
# 'NoneType' object is not callable
# 4
# 'NoneType' object is not callable
# 3
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 2
# 7
# 'NoneType' object is not callable
# 'NoneType' object is not callable
# 4
# 'NoneType' object is not callable
# 3
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 'NoneType' object has no attribute 'findPrevious'
# 2
# 11. Pesquisados
